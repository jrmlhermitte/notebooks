# %%
from pylab import *
import h5py
ion()
# %matplotlib notebook

# %%
f = h5py.File("data/0776-droplettestimg.hd5")
img = np.copy(f['img'])
mask = np.copy(f['/mask'])
rids = np.copy(f['rids'])
rids_low = np.copy(f['rids_low'])
rids_high = np.copy(f['rids_high'])
mask_low = (rids_low < 300)*mask
mask_high = (rids_high > 0)*mask
x0 = f['x0']
y0 = f['y0']

# %%
figure(1);clf();imshow(img*mask)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
figure(2);clf();imshow(mask_low)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
figure(3);clf();imshow(mask_high)
# Out:
# <img src="data:image/png;base64,..." width="640">
